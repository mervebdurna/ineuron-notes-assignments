# %% [markdown]
# # Lists

# %%
l = [1,2,3,4,5,'Merve',True,5.46,['a','b','c']]
l
# Out:
# [1, 2, 3, 4, 5, 'Merve', True, 5.46, ['a', 'b', 'c']]

# %%
len(l)
# Out:
# 9

# %%
l[0]
# Out:
# 1

# %%
l[-1]
# Out:
# ['a', 'b', 'c']

# %%
# upper bound is excluded
l[0:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# it is need to be reassigne to keep reverse list 
l[::-1]
# Out:
# [['a', 'b', 'c'], 5.46, True, 'Merve', 5, 4, 3, 2, 1]

# %%
l[2:5:2]
# Out:
# [3, 5]

# %%
# no error with upper bound
l[0:122:2]
# Out:
# [1, 3, 5, True, ['a', 'b', 'c']]

# %%
l[0:8:-1]
# Out:
# []

# %%
l[:4]
# Out:
# [1, 2, 3, 4]

# %%
l + [23,23,23]
# Out:
# [1, 2, 3, 4, 5, 'Merve', True, 5.46, ['a', 'b', 'c'], 23, 23, 23]

# %%
l*2
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  'Merve',
#  True,
#  5.46,
#  ['a', 'b', 'c'],
#  1,
#  2,
#  3,
#  4,
#  5,
#  'Merve',
#  True,
#  5.46,
#  ['a', 'b', 'c']]

# %%
2 in l
# Out:
# True

# %%
8 in l
# Out:
# False

# %%
# because l include str , int , list and ..
max(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-fd8eeca349cc> in <module>
# ----> 1 max(l)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# max works with all numeric list
l1=[1,2,3,4,5,6]
max(l1)
# Out:
# 6

# %%
# max works with all string list based on alphabetical order
l2 = ['Merve','Bayram','Durna']
max(l2)
# Out:
# 'Merve'

# %%
min(l2)
# Out:
# 'Bayram'

# %%
l=[1, 2, 3, 4, 5, 'Merve', True, 5.46, ['a', 'b', 'c']]

# %%
l.append('Bayram Durna')
l
# Out:
# [1, 2, 3, 4, 5, 'Merve', True, 5.46, ['a', 'b', 'c'], 'Bayram Durna']

# %%
l.pop(0)
l
# Out:
# [2, 3, 4, 5, 'Merve', True, 5.46, ['a', 'b', 'c'], 'Bayram Durna']

# %%
l.pop(6)
# Out:
# 5.46

# %%
# if there is no particular index, it will remove the last element 
l.pop()
# Out:
# 'Bayram Durna'

# %%
# reversefunction reverse the list  permanently
l.reverse()
l
# Out:
# [['a', 'b', 'c'], True, 'Merve', 5, 4, 3, 2]

# %%
# slicing reverse operation is not permenant, to make it permanent need to re-assign
l[::-1]
l
# Out:
# [['a', 'b', 'c'], True, 'Merve', 5, 4, 3, 2]

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-fb07ac7c73ab> in <module>
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'bool' and 'list'

# %%
l3 = [1,2,5,3,7,2]
l3.sort()
l3
# Out:
# [1, 2, 2, 3, 5, 7]

# %%
l3.sort(reverse = True)
l3
# Out:
# [7, 5, 3, 2, 2, 1]

# %%
l4 =[[1,2,3],[4,5,6],[7,8,12]]
l4[2]
# Out:
# [7, 8, 12]

# %%
l4[2][0:2]
# Out:
# [7, 8]

# %%
l4[0][1]
# Out:
# 2

# %%
l5=[1,2,3,4,5,'merve',[3,4,5],'3.45',True]
l5
# Out:
# [1, 2, 3, 4, 5, 'merve', [3, 4, 5], '3.45', True]

# %%
l5.count(3)
# Out:
# 1

# %%
l
# Out:
# [['a', 'b', 'c'], True, 'Merve', 5, 4, 3, 2]

# %%
l.append('Ineuron')
l
# Out:
# [['a', 'b', 'c'], True, 'Merve', 5, 4, 3, 2, 'Ineuron', 'Ineuron']

# %%
# extend append a list to list not item itself
l.extend('merve')

# %%
l
# Out:
# [['a', 'b', 'c'],
#  True,
#  'Merve',
#  5,
#  4,
#  3,
#  2,
#  'Ineuron',
#  'Ineuron',
#  'm',
#  'e',
#  'r',
#  'v',
#  'e']

# %%
l.append('test')

# %%
l
# Out:
# [['a', 'b', 'c'],
#  True,
#  'Merve',
#  5,
#  4,
#  3,
#  2,
#  'Ineuron',
#  'Ineuron',
#  'm',
#  'e',
#  'r',
#  'v',
#  'e',
#  'test']

# %%
l.extend('test')
l
# Out:
# [['a', 'b', 'c'],
#  True,
#  'Merve',
#  5,
#  4,
#  3,
#  2,
#  'Ineuron',
#  'Ineuron',
#  'm',
#  'e',
#  'r',
#  'v',
#  'e',
#  'test',
#  't',
#  'e',
#  's',
#  't']

# %%
# need to extend with iterable object like str , list ,etc
l.extend(45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-5006269718c1> in <module>
#       1 # need to extend with iterable object like str , list ,etc
# ----> 2 l.extend(45)
#
# TypeError: 'int' object is not iterable

# %%
l.extend(['test2'])

# %%
l
# Out:
# [['a', 'b', 'c'],
#  True,
#  'Merve',
#  5,
#  4,
#  3,
#  2,
#  'Ineuron',
#  'Ineuron',
#  'm',
#  'e',
#  'r',
#  'v',
#  'e',
#  'test',
#  't',
#  'e',
#  's',
#  't',
#  'test2']

# %%
# index of particular element
l.index('Merve')
# Out:
# 2

# %%
l.append('Merve')
l
# Out:
# [['a', 'b', 'c'],
#  True,
#  'Merve',
#  5,
#  4,
#  3,
#  2,
#  'Ineuron',
#  'Ineuron',
#  'm',
#  'e',
#  'r',
#  'v',
#  'e',
#  'test',
#  't',
#  'e',
#  's',
#  't',
#  'test2',
#  'Merve',
#  'Merve']

# %%
# If there are many particular variable Index return the first index of them 
l.index('Merve')
# Out:
# 2

# %%
l7 =[1,2,3,4,5]
l7.insert(1,[1,2,3,4,5])

# %%
l7
# Out:
# [1, [1, 2, 3, 4, 5], 2, 3, 4, 5]

# %%
# pop remove last element if not passed index parameter
l7.pop()
l7
# Out:
# [1, [1, 2, 3, 4, 5], 2, 3, 4]

# %%
# if we give particular index to pop , pop will remove the given index element
l7.pop(1)
# Out:
# [1, 2, 3, 4, 5]

# %%
l7
# Out:
# [1, 2, 3, 4]

# %%
# remove the elements based on values not index
l7.remove(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-820979df0719> in <module>
# ----> 1 l7.remove(5)
#
# ValueError: list.remove(x): x not in list

# %%
l7.remove(3)

# %%
l7
# Out:
# [1, 2, 4]

# %% [markdown]
# Note : differences between pop and remove is that; remove function remove the element based on value , pop remove the element based on index

# %%
l8 = [0,1,2,3,4,5]
l8[2]='Merve' # item assignment

# %%
l8
# Out:
# [0, 1, 'Merve', 3, 4, 5]

# %%
# strings are not support item assignment
s = 'Merve'
s[2] = '*'
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-429a4064a6a7> in <module>
#       1 # strings are not support item assignment
#       2 s = 'Merve'
# ----> 3 s[2] = '*'
#       4 s
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Note : if you can perform item assignment it is mean the element is mutable like list
# if not it is immutable like strings.

# %% [markdown]
# # Tuples

# %%
t = (1,2,3,4,'Merve',True,1==2)
type(t)
# Out:
# tuple

# %%
t
# Out:
# (1, 2, 3, 4, 'Merve', True, False)

# %%
t[2]
# Out:
# 3

# %%
t[-1]
# Out:
# False

# %%
t[2:6]
# Out:
# (3, 4, 'Merve', True)

# %% [markdown]
# same slicing and indexin operation with lists

# %%
t[0:5:2]
# Out:
# (1, 3, 'Merve')

# %%
t[4]= 'mervebdurna'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-fcb0c90fcfc5> in <module>
# ----> 1 t[4]= 'mervebdurna'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# tuples are immutable we can't perform item asignment

# %%
t.count(3)
# Out:
# 1

# %%
t.index('Merve')
# Out:
# 4

# %%
t1 = ('bayram','durna')

# %%
# immutability is about existing item assignment, so we can add more items to the tuples
t = t+t1

# %%
t
# Out:
# (1, 2, 3, 4, 'Merve', True, False, 'bayram', 'durna')

# %%
l = list(t)
l
# Out:
# [1, 2, 3, 4, 'Merve', True, False, 'bayram', 'durna']

# %%
t2 = tuple(l)
t2
# Out:
# (1, 2, 3, 4, 'Merve', True, False, 'bayram', 'durna')

# %%
str(t2)
# Out:
# "(1, 2, 3, 4, 'Merve', True, False, 'bayram', 'durna')"

# %% [markdown]
# # Dictionaries

# %%
d = {'one':1,'two' : 2, 'three': 3}
d
# Out:
# {'one': 1, 'two': 2, 'three': 3}

# %%
d[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-123a9cc6df61> in <module>
# ----> 1 d[0]
#
# KeyError: 0

# %%
d['one']
# Out:
# 1

# %%
d['one':'three']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-80dc053bd6c5> in <module>
# ----> 1 d['one':'three']
#
# TypeError: unhashable type: 'slice'

# %%
type(d)
# Out:
# dict

# %%
d1 = {1}
type(d1)
# Out:
# set

# %%
d2 = {}
type(d2)
# Out:
# dict

# %%
d3 ={'key1' : 1, 'key2':'Python', 'key3': (1,'Python',2,3,4,5)}
d3
# Out:
# {'key1': 1, 'key2': 'Python', 'key3': (1, 'Python', 2, 3, 4, 5)}

# %%
'Python' in d3['key3']
# Out:
# True

# %%
d4 = {'name' :'mErve', 'surname' : 'bayram', 'name':'Merve'}

# %%
d4
# Out:
# {'name': 'Merve', 'surname': 'bayram'}

# %% [markdown]
# name takes the last assignment , SO always make sure that your keys are unique. values can be same

# %%
# new item creation
d4['test'] = 87

# %%
d4
# Out:
# {'name': 'Merve', 'surname': 'bayram', 'test': 87}

# %%
# item value changes
d4['test'] = '8787'
d4
# Out:
# {'name': 'Merve', 'surname': 'bayram', 'test': '8787'}

# %%
d5 = {2123 : 'xyz'}
d5
# Out:
# {2123: 'xyz'}

# %%
d6 = {(1,2,3) : 'xyz'}
d6
# Out:
# {(1, 2, 3): 'xyz'}

# %%
# key must be immutable like tuple , str . Can not be a list,set
d7 = {[1,2,3] : 'Merve'}
d7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-644194261474> in <module>
#       1 # key must be immutable like tuple , str . Can not be a list,set
# ----> 2 d7 = {[1,2,3] : 'Merve'}
#       3 d7
#
# TypeError: unhashable type: 'list'

# %%
d8= {{'2':3} : 'Merve'}
d8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-1b13cc627620> in <module>
# ----> 1 d8= {{'2':3} : 'Merve'}
#       2 d8
#
# TypeError: unhashable type: 'dict'

# %%
d6 + d8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-caaf2bd3bcef> in <module>
# ----> 1 d6 + d8
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %% [markdown]
# dict doesnt have combinatin operation

# %%
d3
# Out:
# {'key1': 1, 'key2': 'Python', 'key3': (1, 'Python', 2, 3, 4, 5)}

# %%
d3.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
d3.values()
# Out:
# dict_values([1, 'Python', (1, 'Python', 2, 3, 4, 5)])

# %%
# return list of tuples
d3.items()
# Out:
# dict_items([('key1', 1), ('key2', 'Python'), ('key3', (1, 'Python', 2, 3, 4, 5))])

# %% [markdown]
# # Set

# %%
s = {1,2,3,4,5}
type(s)
# Out:
# set

# %%
s1={1,2,3,4,5,6,7,8,4,4,5,2}
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# Automatically set removed repeated elements in set. Just return uniqe elements

# %%
s2 = {123,437,23,4568,348}
s2
# Out:
# {23, 123, 348, 437, 4568}

# %% [markdown]
# set seems like automatically sort elements but it is not !!!

# %%
s3 = {'merve','bayram','durna'}
s3
# Out:
# {'bayram', 'durna', 'merve'}

# %%
s4 ={'merve','bayram','durna',1,2,3,4,2345,5,'6'}

# %%
s4
# Out:
# {1, 2, 3, 4, 5, '6', 'bayram', 'durna', 'merve'}

# %%
s4[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-171-46b378a65530> in <module>
# ----> 1 s4[3]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# we can't perfom slicing and indexing element on set

# %%
list(s3)[2] # after convert list we can perform indexing and slcing
# Out:
# 'merve'

# %%
tuple(s3)[2] # after convert list we can perform indexing and slcing
# Out:
# 'merve'

# %%
l = [1,2,3,4,5,5,6,7,7,7,8,8]
#to remove duplicates
list(set(l))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
s3.add(4)
s3
# Out:
# {4, 'bayram', 'durna', 'merve'}

# %%
s3.add(4) # it is not add as the set already has 4
s3
# Out:
# {4, 'bayram', 'durna', 'merve'}

# %%
s3.add([1,2,3,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-54c0e84284d7> in <module>
# ----> 1 s3.add([1,2,3,4])
#
# TypeError: unhashable type: 'list'

# %%
s4={(1,2,3,4),5,6,7}
s4
# Out:
# {(1, 2, 3, 4), 5, 6, 7}

# %%
s5={[1,2,3,4],5,6,7}
s5
# you can't keep mutable object in the set like list , but you can store tuples
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-4516998aade0> in <module>
# ----> 1 s5={[1,2,3,4],5,6,7}
#       2 s5
#       3 # you can't keep mutable object in the set like list , but you can store tuples
#
# TypeError: unhashable type: 'list'

# %%
s4.remove(5)
s4
# Out:
# {(1, 2, 3, 4), 6, 7}

# %%
s4.remove(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-192-45b5026485a4> in <module>
# ----> 1 s4.remove(5)
#
# KeyError: 5

# %%
s4.discard(5) # remove if exist , if not don't do anything: diff between remove and discard
